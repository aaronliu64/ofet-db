# %% [markdown]
# ## Data Insert Exercises
#
# In this set of exercises, you will practice a series of transactions using a dataset of solution-based experiments. You will find the data you need under `data\solution_experiments.xlsx`.
#
# The first two sheets `solvent` and `polymer` contain a list of chemicals that are contained in a hypothetical laboratory storage. The third sheet, `solution`, contains a list of solutions that a hypothetical student named Jason, has made in the last several months.

# %%
# Import Libraries

import requests
import json
import pandas as pd
import bibtexparser #API for requesting DOI information
import pprint as pp #The function pp.pprint helps with better visualizing nested key-value information
import psycopg2 as pg # Postgres python
import numpy as np
import sys
from psycopg2.extensions import AsIs
# Out:
# C:\Users\Aaron\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
## Functions

# Adapters necessary for converting python data types to PostgreSQL compatible data types 
def addapt_numpy_float64(numpy_float64):
    return AsIs(numpy_float64)

def addapt_numpy_int64(numpy_int64):
    return AsIs(numpy_int64)

def nan_to_null(f,
        _NULL=AsIs('NULL'),
        _Float=pg.extensions.Float):
    if not np.isnan(f):
        return _Float(f)
    return _NULL

pg.extensions.register_adapter(np.float64, addapt_numpy_float64)
pg.extensions.register_adapter(np.int64, addapt_numpy_int64)
pg.extensions.register_adapter(float, nan_to_null)

def connect(params_dict):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = pg.connect(**params_dict)
    except (Exception, pg.DatabaseError) as error:
        print(error)
        sys.exit(1) 
    print("Connection successful")
    return conn

def pg_query(sql, tup):
    
    try:
        # Database connection
        conn = pg.connect(**conn_kwargs)
        cur = conn.cursor()
        
        # Pass SQL query, using string and placeholders
        cur.execute(sql, tup)
        
#         # Fetch result
#         fetched = cur.fetchone()[0]
        
        # Commit result
        conn.commit()
        print("Operation Successful")

        cur.close()
        conn.close()
        
    except (Exception, pg.DatabaseError) as error:
        # If database connection unsuccessful, then close connection 
        print("Error: %s" % error)
        conn.rollback()
        cur.close()
        conn.close()
    
    return

# %%
conn_kwargs = {
    "host"      : "localhost",
    "database"  : "test", ## FILL IN CONNECTION DETAILS HERE
    "user"      : "postgres",
    "password"  : "Rahul2411!",
    "port"      : "5432",
}

def connect(**params_dict):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = pg.connect(**params_dict)
    except (Exception, pg.DatabaseError) as error:
        print(error)
        sys.exit(1) 
    print("Connection successful")
    return conn

conn = connect(**conn_kwargs)

conn.close()
print("Connection Closed")
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
# Connection Closed

# %% [markdown]
# ### 1. Create Polymer and Solvent Tables
#
# First, please create from scratch two tables which contain the chemical inventory of the laboratory (Solvent and Polymer).
#
# * Solvent contains three attributes: a unique identifier given from its PubChem CID, its IUPAC name, and boiling points
# * Polymer should contain a unique identifier of your choice (e.g., "polymer_id"), two columns for its common name and its full name, and three fields for molecular weight information (Mn, Mw, dispersity)
#
# The primary key for `solvent` should be the PubChem CID, and the primary key for `polymer` should be a one that you generate. You may use the `SERIAL` data type to facilitate automatic key generation for new rows. Make sure you add `UNIQUE` constraints that properly account for the real-world scenario.

# %%
conn = connect(**conn_kwargs)

cur = conn.cursor()

sql = '''

    DROP TABLE IF EXISTS SOLVENT;
    
    CREATE TABLE SOLVENT (
        pubchem_cid         INT             PRIMARY KEY,             
        iupac_name          VARCHAR(50),
        boiling_point       FLOAT,
        UNIQUE(iupac_name)
    );
    
    
    DROP TABLE IF EXISTS POLYMER;
    
    CREATE TABLE POLYMER (
        polymer_id          SERIAL          PRIMARY KEY,
        common_name         VARCHAR(500),
        iupac_name          VARCHAR(500),
        Mn       FLOAT,
        Mw       FLOAT,
        dispersity        FLOAT,
        UNIQUE(common_name,iupac_name,Mn,Mw,dispersity)
    );
'''

cur.execute(sql)
conn.commit()

print("Operation successful")
conn.close()
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
# Operation successful

# %% [markdown]
# ### 2. Create a Record of Solutions
#
# Next, we must create a table to store new experimental records of solutions that are made from the laboratory reagents available in inventory. Recently, Jason has only been interested in testing the solubility of single polymers in solution. In his digital lab notebook, he has written down the date he made the solution, the concentration of the solution, and what polymer and solvent he used. Usually, Jason was a good student and wrote down the batch information (molecular weights, dispersity) of the polymer, but sometimes he was an idiot and forgot. Regardless, we should record all of the data points.
#
# 1. Create an entity-relationship diagram that shows the connections between polymer, solvent, and solution.
#
# 2. Create a table `solution` that accurately models the conceptual schema you generated in the ERD.
#
# `solution` should contain five attributes: This includes:
#
# * A primary key (a solution identifier)
# * Two foreign keys (referencing the polymer and solvent table)
# * Two fields that describe the solution concentration and the date the solution was created
#
# **Warning**: Do not use the given dataset columns to decide how you actually name your columns. Name your attributes in a way that is friendly to programming. For this example, feel free to ignore units. We will deal with that another day.

# %%
sql = '''

DROP TABLE IF EXISTS SOLUTION;

CREATE TABLE SOLUTION(
    solution_id    SERIAL   PRIMARY KEY,
    solution_concentration   FLOAT,
    solvent_id     INT,
    polymer_id     INT,
    date_created   DATE,
    
    FOREIGN KEY(polymer_id) REFERENCES POLYMER(polymer_id)
            ON DELETE SET NULL ON UPDATE CASCADE,
    FOREIGN KEY(solvent_id) REFERENCES SOLVENT(pubchem_cid)
            ON DELETE SET NULL ON UPDATE CASCADE
)
'''



conn = connect(**conn_kwargs)

cur = conn.cursor()

cur.execute(sql)
conn.commit()

print("Operation successful")
conn.close()
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
# Operation successful

# %% [markdown]
# ### 3. Populate the Lab Inventory
#
# In this example, you can pretend that you exported Sheets 1 and 2 of solution_experiments.xlsx from an online inventory manager, and you want to input it into your own database. Upload the inventory in sheets 1 and 2 to `polymer` and `solvent`.
#
# As a note: sometimes, the online manager accidentally duplicates records, so you want to ensure that no duplicates exist in your local copy.

# %%
db = pd.ExcelFile('data/solution_experiments.xlsx')
df_solvent = db.parse('solvent')
df_polymer = db.parse('polymer')
df_solution = db.parse('solution')

# %%
#Inserting into solvent table

sql = '''
INSERT INTO SOLVENT (%s) VALUES %s
'''
columns = list(df_solvent.columns)

for row in df_solvent.itertuples(index=False):
    values = tuple(row)
    tup = (AsIs(','.join(columns)),values)
    pg_query(sql,tup)
# Out:
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful

# %%
#Inserting into polymer table

sql = '''
INSERT INTO POLYMER (%s) VALUES %s
ON CONFLICT(common_name,iupac_name,Mn,Mw,dispersity) DO NOTHING
'''
columns = list(df_polymer.columns)

for row in df_polymer.itertuples(index=False):
    values = (tuple(row))
    tup = (AsIs(','.join(columns)),values)
    pg_query(sql,tup)
# Out:
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful

# %% [markdown]
# ### 4. Update Jason's Experimental Records
#
# Using the "Solution" sheet in the Excel file, figure out a way to import Jason's historical record of solution-based experiments into the `solution` table you made in PostgreSQL. Make sure you properly tailor Jason's dataset to the schema that you created in **Part 2**.
#
# Hints:
# * You may have to do some python pre-processing to generate the tuple you want. Don't be afraid to make a few helper functions that do that.
# * Jason is not going to write PubChem IDs in his laboratory notebook, because he's not insane. You will have to find a way to look up the PubChem ID that is associated with a given solvent name. You might be able to do this in your SQL query. More information: https://dba.stackexchange.com/questions/46410/how-do-i-insert-a-row-which-contains-a-foreign-key
# * Similarly, you're not putting all of the polymer information into your solution table, because that would be redundant. Instead, you need to look up which polymer he used from the known inventory, and assign the polymer_id that way
#
# If the link above does not help, try to find your own resources! Programming isn't always easy, but this is a standard transaction that many other people have probably tried to do. Learn how to learn!

# %%
#Inserting into solution table

# Establish a connection to the PostgreSQL database
conn = connect(**conn_kwargs)

# Create a cursor object to execute SQL queries
cur = conn.cursor()

# Loop through each row of the DataFrame and insert the data into the solution table
for _, row in df_solution.iterrows():
    
    #print(row)
    
    # Retrieve the solvent_id based on the solvent name from the solvent table
    cur.execute("SELECT pubchem_cid FROM solvent WHERE iupac_name = %s", (row['Solvent Name'],))
    solvent_id = cur.fetchone()[0]  # Assuming there's only one matching solvent
    
    # Check if at least one of the required columns has a non-null value
    if pd.notnull(row['Mw (kg/mol)']) or pd.notnull(row['Mn (kg/mol)']) or pd.notnull(row['PDI']):
        # Retrieve the polymer_id based on the polymer, molecular weight, molecular number, and dispersity from the polymer table
        if pd.notnull(row['Mw (kg/mol)']) and pd.notnull(row['Mn (kg/mol)']) and pd.notnull(row['PDI']):
            # If all required columns have non-null values, use the exact match query
            cur.execute("SELECT polymer_id FROM polymer WHERE common_name = %s AND mw = %s AND mn = %s AND dispersity = %s",
                        (row['Polymer Used'], row['Mw (kg/mol)'], row['Mn (kg/mol)'], row['PDI']))
        else:
            # If any of the required columns have null values, use a query with null handling
            cur.execute("SELECT polymer_id FROM polymer WHERE common_name = %s AND (mw = %s OR mw IS NULL) AND (mn = %s OR mn IS NULL) AND (dispersity = %s OR dispersity IS NULL)",
                        (row['Polymer Used'], row['Mw (kg/mol)'], row['Mn (kg/mol)'], row['PDI']))
            
        polymer_id = cur.fetchone()[0]  # Assuming there's only one matching polymer
        
        # Insert the data into the solution table
        cur.execute("INSERT INTO solution (solvent_id, polymer_id, solution_concentration, date_created) VALUES (%s, %s, %s, %s)",
                    (solvent_id, polymer_id, row['Solution Concentration (mg/mL)'], row['Date Created']))

# Commit the changes to the database
conn.commit()

# Close the cursor and the connection
cur.close()
conn.close()
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      20.0
# Mw (kg/mol)                                     104.0
# PDI                                               5.2
# Date Created                      2020-10-16 00:00:00
# Name: 0, dtype: object
# Solution Concentration (mg/mL)                    7.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      20.0
# Mw (kg/mol)                                     104.0
# PDI                                               5.2
# Date Created                      2020-10-08 00:00:00
# Name: 1, dtype: object
# Solution Concentration (mg/mL)                    8.5
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      20.0
# Mw (kg/mol)                                     104.0
# PDI                                               5.2
# Date Created                      2020-10-12 00:00:00
# Name: 2, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      20.0
# Mw (kg/mol)                                     104.0
# PDI                                               5.2
# Date Created                      2020-10-17 00:00:00
# Name: 3, dtype: object
# Solution Concentration (mg/mL)                   12.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      20.0
# Mw (kg/mol)                                     104.0
# PDI                                               5.2
# Date Created                      2020-10-21 00:00:00
# Name: 4, dtype: object
# Solution Concentration (mg/mL)                   14.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      20.0
# Mw (kg/mol)                                     104.0
# PDI                                               5.2
# Date Created                      2020-09-08 00:00:00
# Name: 5, dtype: object
# Solution Concentration (mg/mL)                   16.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      20.0
# Mw (kg/mol)                                     104.0
# PDI                                               5.2
# Date Created                      2020-09-11 00:00:00
# Name: 6, dtype: object
# Solution Concentration (mg/mL)                   18.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      20.0
# Mw (kg/mol)                                     104.0
# PDI                                               5.2
# Date Created                      2020-09-14 00:00:00
# Name: 7, dtype: object
# Solution Concentration (mg/mL)                   25.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      20.0
# Mw (kg/mol)                                     104.0
# PDI                                               5.2
# Date Created                      2020-09-17 00:00:00
# Name: 8, dtype: object
# Solution Concentration (mg/mL)                    3.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      20.0
# Mw (kg/mol)                                     104.0
# PDI                                               5.2
# Date Created                      2020-08-31 00:00:00
# Name: 9, dtype: object
# Solution Concentration (mg/mL)                    8.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                    20.052
# Mw (kg/mol)                                     54.79
# PDI                                              2.73
# Date Created                      2020-09-04 00:00:00
# Name: 10, dtype: object
# Solution Concentration (mg/mL)                   12.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                    20.052
# Mw (kg/mol)                                     54.79
# PDI                                              2.73
# Date Created                      2020-09-26 00:00:00
# Name: 11, dtype: object
# Solution Concentration (mg/mL)                   27.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                    20.052
# Mw (kg/mol)                                     54.79
# PDI                                              2.73
# Date Created                      2020-09-29 00:00:00
# Name: 12, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      29.0
# Mw (kg/mol)                                      91.0
# PDI                                              3.14
# Date Created                      2020-10-09 00:00:00
# Name: 13, dtype: object
# Solution Concentration (mg/mL)                    6.5
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      29.0
# Mw (kg/mol)                                      91.0
# PDI                                              3.14
# Date Created                      2020-10-13 00:00:00
# Name: 14, dtype: object
# Solution Concentration (mg/mL)                    0.5
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      43.0
# Mw (kg/mol)                                     102.0
# PDI                                               2.0
# Date Created                      2020-10-18 00:00:00
# Name: 15, dtype: object
# Solution Concentration (mg/mL)                   0.75
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      43.0
# Mw (kg/mol)                                     102.0
# PDI                                               2.0
# Date Created                      2020-10-22 00:00:00
# Name: 16, dtype: object
# Solution Concentration (mg/mL)                    1.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      43.0
# Mw (kg/mol)                                     102.0
# PDI                                               2.0
# Date Created                      2020-09-01 00:00:00
# Name: 17, dtype: object
# Solution Concentration (mg/mL)                    2.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      43.0
# Mw (kg/mol)                                     102.0
# PDI                                               2.0
# Date Created                      2020-09-12 00:00:00
# Name: 18, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      43.0
# Mw (kg/mol)                                     102.0
# PDI                                               2.0
# Date Created                      2020-09-15 00:00:00
# Name: 19, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      44.0
# Mw (kg/mol)                                     110.0
# PDI                                               2.5
# Date Created                      2020-09-18 00:00:00
# Name: 20, dtype: object
# Solution Concentration (mg/mL)                    2.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      44.0
# Mw (kg/mol)                                     110.0
# PDI                                               2.5
# Date Created                      2020-06-27 00:00:00
# Name: 21, dtype: object
# Solution Concentration (mg/mL)                    4.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      44.0
# Mw (kg/mol)                                     110.0
# PDI                                               2.5
# Date Created                      2020-07-23 00:00:00
# Name: 22, dtype: object
# Solution Concentration (mg/mL)                    6.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      44.0
# Mw (kg/mol)                                     110.0
# PDI                                               2.5
# Date Created                      2020-07-25 00:00:00
# Name: 23, dtype: object
# Solution Concentration (mg/mL)                    8.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      44.0
# Mw (kg/mol)                                     110.0
# PDI                                               2.5
# Date Created                      2020-08-06 00:00:00
# Name: 24, dtype: object
# Solution Concentration (mg/mL)                    9.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      44.0
# Mw (kg/mol)                                     110.0
# PDI                                               2.5
# Date Created                      2020-08-14 00:00:00
# Name: 25, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      44.0
# Mw (kg/mol)                                     110.0
# PDI                                               2.5
# Date Created                      2020-10-10 00:00:00
# Name: 26, dtype: object
# Solution Concentration (mg/mL)                   12.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      44.0
# Mw (kg/mol)                                     110.0
# PDI                                               2.5
# Date Created                      2020-10-14 00:00:00
# Name: 27, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      50.0
# Mw (kg/mol)                                     193.5
# PDI                                              3.87
# Date Created                      2020-10-19 00:00:00
# Name: 28, dtype: object
# Solution Concentration (mg/mL)                    4.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      55.0
# Mw (kg/mol)                                     199.0
# PDI                                              3.62
# Date Created                      2020-08-07 00:00:00
# Name: 29, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      55.0
# Mw (kg/mol)                                     152.0
# PDI                                              2.76
# Date Created                      2020-08-15 00:00:00
# Name: 30, dtype: object
# Solution Concentration (mg/mL)                    2.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      66.0
# Mw (kg/mol)                                     204.0
# PDI                                               3.1
# Date Created                      2020-09-27 00:00:00
# Name: 31, dtype: object
# Solution Concentration (mg/mL)                    6.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      66.0
# Mw (kg/mol)                                     204.0
# PDI                                               3.1
# Date Created                      2020-09-02 00:00:00
# Name: 32, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      66.0
# Mw (kg/mol)                                     204.0
# PDI                                               3.1
# Date Created                      2020-06-14 00:00:00
# Name: 33, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      66.0
# Mw (kg/mol)                                     204.0
# PDI                                               3.1
# Date Created                      2020-06-15 00:00:00
# Name: 34, dtype: object
# Solution Concentration (mg/mL)                    4.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      66.0
# Mw (kg/mol)                                     204.0
# PDI                                               3.1
# Date Created                      2020-06-16 00:00:00
# Name: 35, dtype: object
# Solution Concentration (mg/mL)                    7.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      66.0
# Mw (kg/mol)                                     204.0
# PDI                                               3.1
# Date Created                      2020-06-17 00:00:00
# Name: 36, dtype: object
# Solution Concentration (mg/mL)                    8.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      66.0
# Mw (kg/mol)                                     204.0
# PDI                                               3.1
# Date Created                      2020-07-30 00:00:00
# Name: 37, dtype: object
# Solution Concentration (mg/mL)                    6.5
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      67.0
# Mw (kg/mol)                                     100.0
# PDI                                               3.0
# Date Created                      2020-09-05 00:00:00
# Name: 38, dtype: object
# Solution Concentration (mg/mL)                    4.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      68.0
# Mw (kg/mol)                                     250.0
# PDI                                              3.67
# Date Created                      2020-08-08 00:00:00
# Name: 39, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      71.0
# Mw (kg/mol)                                     344.0
# PDI                                              4.85
# Date Created                      2020-08-16 00:00:00
# Name: 40, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      74.9
# Mw (kg/mol)                                     292.2
# PDI                                               3.9
# Date Created                      2020-09-30 00:00:00
# Name: 41, dtype: object
# Solution Concentration (mg/mL)                    1.6
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      77.0
# Mw (kg/mol)                                     279.0
# PDI                                              3.65
# Date Created                      2020-10-23 00:00:00
# Name: 42, dtype: object
# Solution Concentration (mg/mL)                    4.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      90.0
# Mw (kg/mol)                                     299.0
# PDI                                              3.32
# Date Created                      2020-07-09 00:00:00
# Name: 43, dtype: object
# Solution Concentration (mg/mL)                    4.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      90.0
# Mw (kg/mol)                                     299.0
# PDI                                              3.32
# Date Created                      2020-09-09 00:00:00
# Name: 44, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                      94.4
# Mw (kg/mol)                                     255.0
# PDI                                               2.7
# Date Created                      2020-06-28 00:00:00
# Name: 45, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                     110.0
# Mw (kg/mol)                                     501.0
# PDI                                              4.55
# Date Created                      2020-09-28 00:00:00
# Name: 46, dtype: object
# Solution Concentration (mg/mL)                    4.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                     125.0
# Mw (kg/mol)                                     350.0
# PDI                                               2.8
# Date Created                      2020-10-01 00:00:00
# Name: 47, dtype: object
# Solution Concentration (mg/mL)                    3.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                     143.0
# Mw (kg/mol)                                     290.0
# PDI                                              2.03
# Date Created                      2020-10-24 00:00:00
# Name: 48, dtype: object
# Solution Concentration (mg/mL)                    7.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                     143.0
# Mw (kg/mol)                                     290.0
# PDI                                              2.03
# Date Created                      2020-08-09 00:00:00
# Name: 49, dtype: object
# Solution Concentration (mg/mL)                    3.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                     143.0
# Mw (kg/mol)                                     292.0
# PDI                                              2.03
# Date Created                      2020-08-17 00:00:00
# Name: 50, dtype: object
# Solution Concentration (mg/mL)                    4.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                     143.0
# Mw (kg/mol)                                     292.0
# PDI                                              2.03
# Date Created                      2020-05-08 00:00:00
# Name: 51, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                     143.0
# Mw (kg/mol)                                     292.0
# PDI                                              2.03
# Date Created                      2020-05-09 00:00:00
# Name: 52, dtype: object
# Solution Concentration (mg/mL)                    6.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                     143.0
# Mw (kg/mol)                                     292.0
# PDI                                              2.03
# Date Created                      2020-05-10 00:00:00
# Name: 53, dtype: object
# Solution Concentration (mg/mL)                    8.0
# Solvent Name                            chlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                     143.0
# Mw (kg/mol)                                     292.0
# PDI                                              2.03
# Date Created                      2020-05-11 00:00:00
# Name: 54, dtype: object
# Solution Concentration (mg/mL)                    2.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                     250.0
# PDI                                               NaN
# Date Created                      2020-05-12 00:00:00
# Name: 55, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                  DPP-DTT
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-05-13 00:00:00
# Name: 56, dtype: object
# Solution Concentration (mg/mL)                    9.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      10.0
# Mw (kg/mol)                                      14.0
# PDI                                               1.4
# Date Created                      2020-05-14 00:00:00
# Name: 57, dtype: object
# Solution Concentration (mg/mL)                    8.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      10.2
# Mw (kg/mol)                                      48.0
# PDI                                               4.7
# Date Created                      2020-05-15 00:00:00
# Name: 58, dtype: object
# Solution Concentration (mg/mL)                   0.01
# Solvent Name                               1,4-xylene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      10.2
# Mw (kg/mol)                                      48.0
# PDI                                               4.7
# Date Created                      2020-05-16 00:00:00
# Name: 59, dtype: object
# Solution Concentration (mg/mL)                          7.0
# Solvent Name                      1,1,2,2-tetrachloroethane
# Polymer Used                                          N2200
# Mn (kg/mol)                                            12.0
# Mw (kg/mol)                                            23.0
# PDI                                                     1.9
# Date Created                            2020-05-17 00:00:00
# Name: 60, dtype: object
# Solution Concentration (mg/mL)                          3.0
# Solvent Name                      1,1,2,2-tetrachloroethane
# Polymer Used                                          N2200
# Mn (kg/mol)                                            12.0
# Mw (kg/mol)                                            23.0
# PDI                                                     1.9
# Date Created                            2020-05-25 00:00:00
# Name: 61, dtype: object
# Solution Concentration (mg/mL)                          1.0
# Solvent Name                      1,1,2,2-tetrachloroethane
# Polymer Used                                          N2200
# Mn (kg/mol)                                            12.0
# Mw (kg/mol)                                            23.0
# PDI                                                     1.9
# Date Created                            2020-05-26 00:00:00
# Name: 62, dtype: object
# Solution Concentration (mg/mL)                          0.5
# Solvent Name                      1,1,2,2-tetrachloroethane
# Polymer Used                                          N2200
# Mn (kg/mol)                                            12.0
# Mw (kg/mol)                                            23.0
# PDI                                                     1.9
# Date Created                            2020-05-27 00:00:00
# Name: 63, dtype: object
# Solution Concentration (mg/mL)                    2.0
# Solvent Name                            chlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      15.2
# Mw (kg/mol)                                      26.6
# PDI                                              1.75
# Date Created                      2020-07-10 00:00:00
# Name: 64, dtype: object
# Solution Concentration (mg/mL)                    9.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      17.0
# Mw (kg/mol)                                      38.0
# PDI                                              2.23
# Date Created                      2020-06-18 00:00:00
# Name: 65, dtype: object
# Solution Concentration (mg/mL)                    2.0
# Solvent Name                            chlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      20.5
# Mw (kg/mol)                                     50.43
# PDI                                              2.46
# Date Created                      2020-06-19 00:00:00
# Name: 66, dtype: object
# Solution Concentration (mg/mL)                    8.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      22.5
# Mw (kg/mol)                                      72.0
# PDI                                               3.2
# Date Created                      2020-06-20 00:00:00
# Name: 67, dtype: object
# Solution Concentration (mg/mL)                          7.0
# Solvent Name                      1,1,2,2-tetrachloroethane
# Polymer Used                                          N2200
# Mn (kg/mol)                                            22.5
# Mw (kg/mol)                                            72.0
# PDI                                                     3.2
# Date Created                            2020-06-21 00:00:00
# Name: 68, dtype: object
# Solution Concentration (mg/mL)                          3.0
# Solvent Name                      1,1,2,2-tetrachloroethane
# Polymer Used                                          N2200
# Mn (kg/mol)                                            22.5
# Mw (kg/mol)                                            72.0
# PDI                                                     3.2
# Date Created                            2020-08-11 00:00:00
# Name: 69, dtype: object
# Solution Concentration (mg/mL)                          1.0
# Solvent Name                      1,1,2,2-tetrachloroethane
# Polymer Used                                          N2200
# Mn (kg/mol)                                            22.5
# Mw (kg/mol)                                            72.0
# PDI                                                     3.2
# Date Created                            2020-08-19 00:00:00
# Name: 70, dtype: object
# Solution Concentration (mg/mL)                    9.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      30.0
# Mw (kg/mol)                                      91.0
# PDI                                              3.03
# Date Created                      2020-08-10 00:00:00
# Name: 71, dtype: object
# Solution Concentration (mg/mL)                    9.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      35.0
# Mw (kg/mol)                                     124.0
# PDI                                               3.5
# Date Created                      2020-08-18 00:00:00
# Name: 72, dtype: object
# Solution Concentration (mg/mL)                    9.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      41.0
# Mw (kg/mol)                                     123.0
# PDI                                               3.0
# Date Created                      2020-07-28 00:00:00
# Name: 73, dtype: object
# Solution Concentration (mg/mL)                    8.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      46.0
# Mw (kg/mol)                                      82.8
# PDI                                               1.8
# Date Created                      2020-07-29 00:00:00
# Name: 74, dtype: object
# Solution Concentration (mg/mL)                   0.01
# Solvent Name                               1,4-xylene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      46.0
# Mw (kg/mol)                                      82.8
# PDI                                               1.8
# Date Created                      2020-09-20 00:00:00
# Name: 75, dtype: object
# Solution Concentration (mg/mL)                    2.0
# Solvent Name                            chlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      48.3
# Mw (kg/mol)                                      99.5
# PDI                                              2.06
# Date Created                      2020-09-21 00:00:00
# Name: 76, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                    N2200
# Mn (kg/mol)                                      57.0
# Mw (kg/mol)                                     171.0
# PDI                                               3.0
# Date Created                      2020-09-22 00:00:00
# Name: 77, dtype: object
# Solution Concentration (mg/mL)                    8.0
# Solvent Name                            chlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                      64.1
# Mw (kg/mol)                                    132.69
# PDI                                              2.07
# Date Created                      2020-09-23 00:00:00
# Name: 78, dtype: object
# Solution Concentration (mg/mL)                    2.0
# Solvent Name                            chlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                     103.5
# Mw (kg/mol)                                     236.0
# PDI                                              2.28
# Date Created                      2020-09-25 00:00:00
# Name: 79, dtype: object
# Solution Concentration (mg/mL)                    8.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                     108.7
# Mw (kg/mol)                                     250.0
# PDI                                               2.3
# Date Created                      2020-09-24 00:00:00
# Name: 80, dtype: object
# Solution Concentration (mg/mL)                          7.0
# Solvent Name                      1,1,2,2-tetrachloroethane
# Polymer Used                                          N2200
# Mn (kg/mol)                                           108.7
# Mw (kg/mol)                                           250.0
# PDI                                                     2.3
# Date Created                            2020-10-02 00:00:00
# Name: 81, dtype: object
# Solution Concentration (mg/mL)                          3.0
# Solvent Name                      1,1,2,2-tetrachloroethane
# Polymer Used                                          N2200
# Mn (kg/mol)                                           108.7
# Mw (kg/mol)                                           250.0
# PDI                                                     2.3
# Date Created                            2020-10-03 00:00:00
# Name: 82, dtype: object
# Solution Concentration (mg/mL)                          1.0
# Solvent Name                      1,1,2,2-tetrachloroethane
# Polymer Used                                          N2200
# Mn (kg/mol)                                           108.7
# Mw (kg/mol)                                           250.0
# PDI                                                     2.3
# Date Created                            2020-10-04 00:00:00
# Name: 83, dtype: object
# Solution Concentration (mg/mL)                          0.5
# Solvent Name                      1,1,2,2-tetrachloroethane
# Polymer Used                                          N2200
# Mn (kg/mol)                                           108.7
# Mw (kg/mol)                                           250.0
# PDI                                                     2.3
# Date Created                            2020-10-05 00:00:00
# Name: 84, dtype: object
# Solution Concentration (mg/mL)                    2.0
# Solvent Name                            chlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                     163.2
# Mw (kg/mol)                                    394.34
# PDI                                              2.42
# Date Created                      2020-10-06 00:00:00
# Name: 85, dtype: object
# Solution Concentration (mg/mL)                   15.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-10-07 00:00:00
# Name: 86, dtype: object
# Solution Concentration (mg/mL)                   3.75
# Solvent Name                               chloroform
# Polymer Used                                    N2200
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-10-11 00:00:00
# Name: 87, dtype: object
# Solution Concentration (mg/mL)                    7.5
# Solvent Name                            chlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-10-15 00:00:00
# Name: 88, dtype: object
# Solution Concentration (mg/mL)                    7.5
# Solvent Name                                  toluene
# Polymer Used                                    N2200
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-10-20 00:00:00
# Name: 89, dtype: object
# Solution Concentration (mg/mL)                   15.0
# Solvent Name                               1,4-xylene
# Polymer Used                                    N2200
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-04-21 00:00:00
# Name: 90, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                      1-chloronaphthalene
# Polymer Used                                    N2200
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-04-25 00:00:00
# Name: 91, dtype: object
# Solution Concentration (mg/mL)                      10.0
# Solvent Name                      1,3,5-trimethylbenzene
# Polymer Used                                       N2200
# Mn (kg/mol)                                          NaN
# Mw (kg/mol)                                          NaN
# PDI                                                  NaN
# Date Created                         2020-09-06 00:00:00
# Name: 92, dtype: object
# Solution Concentration (mg/mL)                    8.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-06-29 00:00:00
# Name: 93, dtype: object
# Solution Concentration (mg/mL)                    NaN
# Solvent Name                               1,4-xylene
# Polymer Used                                    N2200
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-09-10 00:00:00
# Name: 94, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                            chlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-09-13 00:00:00
# Name: 95, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                                  toluene
# Polymer Used                                    N2200
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-09-16 00:00:00
# Name: 96, dtype: object
# Solution Concentration (mg/mL)                    9.0
# Solvent Name                      1,2-dichlorobenzene
# Polymer Used                                    N2200
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-09-19 00:00:00
# Name: 97, dtype: object
# Solution Concentration (mg/mL)                       5.0
# Solvent Name                      1,3,5-trimethylbenzene
# Polymer Used                                       N2200
# Mn (kg/mol)                                          NaN
# Mw (kg/mol)                                          NaN
# PDI                                                  NaN
# Date Created                         2020-09-03 00:00:00
# Name: 98, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                                  toluene
# Polymer Used                                    N2200
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-06-30 00:00:00
# Name: 99, dtype: object
# Solution Concentration (mg/mL)                    1.0
# Solvent Name                               chloroform
# Polymer Used                                    N2200
# Mn (kg/mol)                                       NaN
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-10-25 00:00:00
# Name: 100, dtype: object
# Solution Concentration (mg/mL)                    0.5
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      1.09
# Mw (kg/mol)                                    1.4279
# PDI                                              1.31
# Date Created                      2020-09-07 00:00:00
# Name: 101, dtype: object
# Solution Concentration (mg/mL)                    2.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       1.9
# Mw (kg/mol)                                     2.755
# PDI                                              1.45
# Date Created                      2020-08-01 00:00:00
# Name: 102, dtype: object
# Solution Concentration (mg/mL)                    1.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       1.9
# Mw (kg/mol)                                     2.755
# PDI                                              1.45
# Date Created                      2020-08-02 00:00:00
# Name: 103, dtype: object
# Solution Concentration (mg/mL)                    0.5
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       1.9
# Mw (kg/mol)                                     2.755
# PDI                                              1.45
# Date Created                      2020-08-03 00:00:00
# Name: 104, dtype: object
# Solution Concentration (mg/mL)                    NaN
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       2.2
# Mw (kg/mol)                                     3.146
# PDI                                              1.43
# Date Created                      2020-08-04 00:00:00
# Name: 105, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       3.2
# Mw (kg/mol)                                      4.48
# PDI                                               1.4
# Date Created                      2020-08-05 00:00:00
# Name: 106, dtype: object
# Solution Concentration (mg/mL)                    3.5
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       3.2
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-08-24 00:00:00
# Name: 107, dtype: object
# Solution Concentration (mg/mL)                    3.5
# Solvent Name                               1,4-xylene
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       3.2
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-08-22 00:00:00
# Name: 108, dtype: object
# Solution Concentration (mg/mL)                    0.5
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       3.2
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-08-23 00:00:00
# Name: 109, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       4.0
# Mw (kg/mol)                                       4.4
# PDI                                               1.1
# Date Created                      2020-07-01 00:00:00
# Name: 110, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       4.6
# Mw (kg/mol)                                      5.98
# PDI                                               1.3
# Date Created                      2020-04-30 00:00:00
# Name: 111, dtype: object
# Solution Concentration (mg/mL)                   15.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       5.1
# Mw (kg/mol)                                       5.1
# PDI                                               1.0
# Date Created                      2020-05-01 00:00:00
# Name: 112, dtype: object
# Solution Concentration (mg/mL)                   15.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       5.6
# Mw (kg/mol)                                     6.608
# PDI                                              1.18
# Date Created                      2020-05-02 00:00:00
# Name: 113, dtype: object
# Solution Concentration (mg/mL)                    2.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       5.6
# Mw (kg/mol)                                    11.592
# PDI                                              2.07
# Date Created                      2020-05-03 00:00:00
# Name: 114, dtype: object
# Solution Concentration (mg/mL)                    1.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       5.6
# Mw (kg/mol)                                    11.592
# PDI                                              2.07
# Date Created                      2020-05-04 00:00:00
# Name: 115, dtype: object
# Solution Concentration (mg/mL)                    0.5
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       5.6
# Mw (kg/mol)                                    11.592
# PDI                                              2.07
# Date Created                      2020-06-02 00:00:00
# Name: 116, dtype: object
# Solution Concentration (mg/mL)                    NaN
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                       5.6
# Mw (kg/mol)                                     6.608
# PDI                                              1.18
# Date Created                      2020-06-07 00:00:00
# ...
# PDI                                              2.04
# Date Created                      2020-04-29 00:00:00
# Name: 152, dtype: object
# Solution Concentration (mg/mL)                    3.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      24.0
# Mw (kg/mol)                                      47.7
# PDI                                            1.9875
# Date Created                      2020-04-18 00:00:00
# Name: 153, dtype: object
# Solution Concentration (mg/mL)                    NaN
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      25.0
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-04-19 00:00:00
# Name: 154, dtype: object
# Solution Concentration (mg/mL)                       1.0
# Solvent Name                      1,2,4-trichlorobenzene
# Polymer Used                                        P3HT
# Mn (kg/mol)                                         25.5
# Mw (kg/mol)                                        37.74
# PDI                                                 1.48
# Date Created                         2020-08-25 00:00:00
# Name: 155, dtype: object
# Solution Concentration (mg/mL)                    1.0
# Solvent Name                               1,4-xylene
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      25.5
# Mw (kg/mol)                                     37.74
# PDI                                              1.48
# Date Created                      2020-05-23 00:00:00
# Name: 156, dtype: object
# Solution Concentration (mg/mL)                    1.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      25.5
# Mw (kg/mol)                                     37.74
# PDI                                              1.48
# Date Created                      2020-07-12 00:00:00
# Name: 157, dtype: object
# Solution Concentration (mg/mL)                       0.1
# Solvent Name                      1,2,4-trichlorobenzene
# Polymer Used                                        P3HT
# Mn (kg/mol)                                         25.5
# Mw (kg/mol)                                        37.74
# PDI                                                 1.48
# Date Created                         2020-06-22 00:00:00
# Name: 158, dtype: object
# Solution Concentration (mg/mL)                    0.1
# Solvent Name                               1,4-xylene
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      25.5
# Mw (kg/mol)                                     37.74
# PDI                                              1.48
# Date Created                      2020-06-23 00:00:00
# Name: 159, dtype: object
# Solution Concentration (mg/mL)                    0.1
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      25.5
# Mw (kg/mol)                                     37.74
# PDI                                              1.48
# Date Created                      2020-06-24 00:00:00
# Name: 160, dtype: object
# Solution Concentration (mg/mL)                    2.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      27.0
# Mw (kg/mol)                                     60.75
# PDI                                              2.25
# Date Created                      2020-06-25 00:00:00
# Name: 161, dtype: object
# Solution Concentration (mg/mL)                    1.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      27.0
# Mw (kg/mol)                                     60.75
# PDI                                              2.25
# Date Created                      2020-06-26 00:00:00
# Name: 162, dtype: object
# Solution Concentration (mg/mL)                    0.5
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      27.0
# Mw (kg/mol)                                     60.75
# PDI                                              2.25
# Date Created                      2020-04-23 00:00:00
# Name: 163, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      29.8
# Mw (kg/mol)                                     56.62
# PDI                                               1.9
# Date Created                      2020-08-13 00:00:00
# Name: 164, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      31.1
# Mw (kg/mol)                                     43.54
# PDI                                               1.4
# Date Created                      2020-08-21 00:00:00
# Name: 165, dtype: object
# Solution Concentration (mg/mL)                    3.5
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      31.1
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-05-06 00:00:00
# Name: 166, dtype: object
# Solution Concentration (mg/mL)                    3.5
# Solvent Name                               1,4-xylene
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      31.1
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-04-26 00:00:00
# Name: 167, dtype: object
# Solution Concentration (mg/mL)                    0.5
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      31.1
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-04-27 00:00:00
# Name: 168, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      33.8
# Mw (kg/mol)                                      50.7
# PDI                                               1.5
# Date Created                      2020-05-18 00:00:00
# Name: 169, dtype: object
# Solution Concentration (mg/mL)                    3.5
# Solvent Name                                  toluene
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      35.0
# Mw (kg/mol)                                      70.0
# PDI                                               2.0
# Date Created                      2020-05-19 00:00:00
# Name: 170, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      36.5
# Mw (kg/mol)                                     62.05
# PDI                                               1.7
# Date Created                      2020-05-20 00:00:00
# Name: 171, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      37.0
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-05-21 00:00:00
# Name: 172, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                               1,4-xylene
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      37.0
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-05-22 00:00:00
# Name: 173, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                        cyclohexylbenzene
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      37.0
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-07-13 00:00:00
# Name: 174, dtype: object
# Solution Concentration (mg/mL)                      10.0
# Solvent Name                      1,2,4-trichlorobenzene
# Polymer Used                                        P3HT
# Mn (kg/mol)                                         37.0
# Mw (kg/mol)                                          NaN
# PDI                                                  NaN
# Date Created                         2020-05-05 00:00:00
# Name: 175, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                                thiophene
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      37.0
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-05-07 00:00:00
# Name: 176, dtype: object
# Solution Concentration (mg/mL)                    1.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      39.5
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-07-02 00:00:00
# Name: 177, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      40.3
# Mw (kg/mol)                                    91.481
# PDI                                              2.27
# Date Created                      2020-07-03 00:00:00
# Name: 178, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                            chlorobenzene
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      40.3
# Mw (kg/mol)                                    91.481
# PDI                                              2.27
# Date Created                      2020-07-04 00:00:00
# Name: 179, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      44.7
# Mw (kg/mol)                                      76.0
# PDI                                               1.7
# Date Created                      2020-07-05 00:00:00
# Name: 180, dtype: object
# Solution Concentration (mg/mL)                      10.0
# Solvent Name                      1,2,4-trichlorobenzene
# Polymer Used                                        P3HT
# Mn (kg/mol)                                         44.7
# Mw (kg/mol)                                         76.0
# PDI                                                  1.7
# Date Created                         2020-07-06 00:00:00
# Name: 181, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      65.5
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-07-07 00:00:00
# Name: 182, dtype: object
# Solution Concentration (mg/mL)                    0.5
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      68.0
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-07-08 00:00:00
# Name: 183, dtype: object
# Solution Concentration (mg/mL)                    1.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      68.0
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-07-14 00:00:00
# Name: 184, dtype: object
# Solution Concentration (mg/mL)                    2.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      68.0
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-07-15 00:00:00
# Name: 185, dtype: object
# Solution Concentration (mg/mL)                    4.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      68.0
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-07-17 00:00:00
# Name: 186, dtype: object
# Solution Concentration (mg/mL)                    8.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      68.0
# Mw (kg/mol)                                       NaN
# PDI                                               NaN
# Date Created                      2020-07-18 00:00:00
# Name: 187, dtype: object
# Solution Concentration (mg/mL)                    3.5
# Solvent Name                                  toluene
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      68.0
# Mw (kg/mol)                                     163.2
# PDI                                               2.4
# Date Created                      2020-07-19 00:00:00
# Name: 188, dtype: object
# Solution Concentration (mg/mL)                    5.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                      90.0
# Mw (kg/mol)                                     207.0
# PDI                                               2.3
# Date Created                      2020-07-20 00:00:00
# Name: 189, dtype: object
# Solution Concentration (mg/mL)                   10.0
# Solvent Name                               chloroform
# Polymer Used                                     P3HT
# Mn (kg/mol)                                     117.4
# Mw (kg/mol)                                     270.0
# PDI                                               2.3
# Date Created                      2020-07-21 00:00:00
# Name: 190, dtype: object
# Solution Concentration (mg/mL)                      10.0
# Solvent Name                      1,2,4-trichlorobenzene
# Polymer Used                                        P3HT
# Mn (kg/mol)                                        117.4
# Mw (kg/mol)                                        270.0
# PDI                                                  2.3
# Date Created                         2020-07-27 00:00:00
# Name: 191, dtype: object

# %% [markdown]
# ### 5. Upload New Experiments
#
# Two weeks later, Jason compiles another dataset with a new set of solutions. After speaking with his advisor, he has actually decided to test a few new solvents to try out. You can find these new solutions within `data/new_experiments.xlsx`
#
# Add these new experiments to the relational database that you have generated.
#
# * Note that the solution table contains reagents that have not previously been added to the inventory. What happens when you try to import the data with the queries you generated above? What type of constraint is this called?
# * Can you figure out how to structure queries or a workflow that will account for this situation? For example: Try inserting the record. If the solvent does not exist, get the PubChem CID using an API, add it to the `solvent` table, and retry the add. Normally, I would also ask you do this with polymers; i.e., if the polymer does not exist, similarly add new information to the `polymer` table, then retry the add -- but for now let's try the exercise with solvent only. You can assume he only experimented on existing polymers.
#
# The below code block contains a simple *Chemical Name to PubChem CID* function. You may use it to facilitate the programming process.

# %%
import pubchempy as pcpy #You may have to pip or conda install pubchempy API. 

#Read more here: https://pubchempy.readthedocs.io/en/latest/

def name2cid(chemName):
    cid = pcpy.get_cids(chemName)
    #if chemname isn't valid, cid will return an empty array. if so, this if statement will return an error message.
    if not cid:
        return 'Please enter a valid name.'
    else:
        return cid

name2cid('chloroform')

# %% [markdown]
# ### Bonus
#
# You may have seen that a lot of these queries can be challenging to program using just psycopg2. Many online articles and tutorials recommend the use of SQLAlchemy to facilitate the generation of queries, and many Python users prefer it because it "requires little knowledge of SQL". Your bonus assignment is to test this theory by exploring SQLAlchemy on your own. For example, can you perform all of the questions in this homework with the help of an SQLAlchemy connection to your database? You are a superstar if you do this entire exercise with SQLAlchemy, and you'll be on your way to helping develop OFETdb. But for starters, try the first few problems.
#
# Here is a tutorial I found, but feel free to find others on YouTube or Google, or just ask ChatGPT.
# https://www.learndatasci.com/tutorials/using-databases-python-postgres-sqlalchemy-and-alembic/
