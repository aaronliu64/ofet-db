# %%
import pandas as pd
import numpy as np
import psycopg2 as pg
import os
from psycopg2.extras import Json
from psycopg2.extensions import AsIs
import functools
import json

# %%
import requests
import bibtexparser
import pprint

# Postgres python
from psycopg2.extras import Json

def addapt_numpy_float64(numpy_float64):
    return AsIs(numpy_float64)

def addapt_numpy_int64(numpy_int64):
    return AsIs(numpy_int64)

def nan_to_null(f,
        _NULL=AsIs('NULL'),
        _Float=pg.extensions.Float):
    if not np.isnan(f):
        return _Float(f)
    return _NULL

pg.extensions.register_adapter(np.float64, addapt_numpy_float64)
pg.extensions.register_adapter(np.int64, addapt_numpy_int64)
pg.extensions.register_adapter(float, nan_to_null)

param_dict = {
    "host"      : "127.0.0.1",
    "database"  : "ofetdb_v2",
    "user"      : "postgres",
    "password"  : "password",
    "port"      : "5432",
}

def connect(params_dict):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
#         print('Connecting to the PostgreSQL database...')
        conn = pg.connect(**params_dict)
    except (Exception, pg.DatabaseError) as error:
        print(error)
        sys.exit(1) 
#     print("Connection successful")
    return conn

def doi2dict(doi):
    #create url
    url = "http://dx.doi.org/" + doi
    
    #create dictionary of http bibtex headers that requests will retrieve from the url
    headers = {"accept": "application/x-bibtex"}
    
    #reqeusts information specified by bibtex from url
    r = requests.get(url, headers = headers).text    
    
    #parse the returned bibtex text to a dictionary
    #NOTE: USE bibtexparser.customization to split strings into list, etc. (https://bibtexparser.readthedocs.io/en/master/bibtexparser.html?highlight=bparser#module-bibtexparser.bparser)
    bibdata = bibtexparser.bparser.BibTexParser().parse(r)
    
    # # print doi metadata
    # pp = pprint.PrettyPrinter(indent=4)
    # pp.pprint(bibdata.entries[0])
    
    #return dict of metadata
    return bibdata.entries[0]

def row_to_json(a):
    
    """Takes a Series object as an input, with columns in dot notation according to 
    ofetdb schema, converts to a json formatted dict. Must use Excel literature/expt template with dot notation"""

    output = {}
    for key, value in a.iteritems():
        if pd.isnull(value) == False: #Only add key:value if not empty in the json
            path = key.split('.')
            target = functools.reduce(lambda d, k: d.setdefault(k, {}), path[:-1], output)
            target[path[-1]] = value
    return output

# %%
fname = '../db_feed/DPPDTT/DPPDTT_dataset_feed_D6_ALcopy.xlsx'
sheetnames = pd.ExcelFile(fname).sheet_names[3:]
# data = {key:None for key in sheetnames}

for SN in sheetnames:
    sheet = pd.read_excel(fname, sheet_name=SN)
    print(SN)
    for i, row in sheet.iterrows():
        entry = row_to_json(row)

        for key in entry.keys():
            if type(entry[key])==dict:
                entry[key]=Json(entry[key])
        
#         print(entry)
        conn = connect(param_dict)
        cur = conn.cursor()
        
        columns = entry.keys()
        values = [entry[column] for column in columns]
        sql = 'insert into %s (%s) values %s ON CONFLICT DO NOTHING'

        try:
            cur.execute(sql, (AsIs(SN), AsIs(','.join(columns)), tuple(values)) )
            conn.commit()
#             print("Operation Successful")
        except (Exception, pg.DatabaseError) as error:
            print("Error: %s" % error)
            conn.rollback()
        
        cur.close()
        conn.close()
    print("Operation Successful")
# sheet = data[sheetnames[0]]
# Out:
# experiment_info
# Operation Successful
# solution
# Operation Successful
# solvent
# Operation Successful
# solution_makeup_solvent
# Operation Successful
# polymer
# Operation Successful
# solution_makeup_polymer
# Operation Successful
# solution_treatment
# Operation Successful
# solution_treatment_order
# Operation Successful
# solution_treatment_step
# Operation Successful
# device_fabrication
# Operation Successful
# substrate_pretreat
# Operation Successful
# substrate_pretreat_step
# Operation Successful
# substrate_pretreat_order
# Operation Successful
# film_deposition
# Operation Successful
# postprocess
# Operation Successful
# postprocess_step
# Operation Successful
# postprocess_order
# Operation Successful
# ofet_process
# Operation Successful
# sample
# Operation Successful

# %%
conn = connect(param_dict)
cur = conn.cursor()

columns = row.keys()
values = [row[column] for column in columns]
sql = 'insert into %s (%s) values %s ON CONFLICT(exp_id) DO NOTHING'

try:
    cur.execute(sql, (AsIs(sheetnames[0]), AsIs(','.join(columns)), tuple(values)) )
    conn.commit()
    print("Operation Successful")
except (Exception, pg.DatabaseError) as error:
    print("Error: %s" % error)
    conn.rollback()
    
cur.close()
conn.close()
# Out:
# Connecting to the PostgreSQL database...
# Connection successful
# Operation Successful

# %%
fname = '../db_feed/DPPDTT/DPPDTT_dataset_feed_D6_measurements.xlsx'
sheetnames = pd.ExcelFile(fname).sheet_names


sheet = pd.read_excel(fname, sheet_name='giwaxs')

for i, row in sheet.iterrows():
    entry = row_to_json(row)

    for key in entry.keys():
        if type(entry[key])==dict:
            entry[key]=Json(entry[key])

#         print(entry)
    conn = connect(param_dict)
    cur = conn.cursor()

    columns = entry.keys()
    values = [entry[column] for column in columns]
    sql = 'insert into measurement (%s) values %s ON CONFLICT DO NOTHING'

    try:
        cur.execute(sql, (AsIs(','.join(columns)), tuple(values)) )
        conn.commit()
#             print("Operation Successful")
    except (Exception, pg.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        
        cur.close()
        conn.close()
        
    print("Operation Successful")
# Out:
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful
# Operation Successful

# %%
values
# Out:
# [315, 159, 'uv_vis_film', <psycopg2._json.Json at 0x24134a27310>]

# %%
sheet = pd.read_excel(fname, sheet_name='ofet_hole')
# print(SN)
for i, row in sheet.iterrows():
    entry = row_to_json(row)

    for key in entry.keys():

        if type(entry[key])==dict:
            entry[key]=Json(entry[key])
# Out:
# {'sample_id': 1, 'data': <psycopg2._json.Json object at 0x0000024134766910>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 2, 'data': <psycopg2._json.Json object at 0x0000024134766670>, 'meta': <psycopg2._json.Json object at 0x0000024134766910>}
# {'sample_id': 3, 'data': <psycopg2._json.Json object at 0x0000024134766910>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 4, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766850>}
# {'sample_id': 5, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 6, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766850>}
# {'sample_id': 7, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766910>}
# {'sample_id': 8, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 9, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766850>}
# {'sample_id': 10, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766910>}
# {'sample_id': 11, 'data': <psycopg2._json.Json object at 0x0000024134766910>, 'meta': <psycopg2._json.Json object at 0x0000024134766850>}
# {'sample_id': 12, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 13, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766850>}
# {'sample_id': 14, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766910>}
# {'sample_id': 15, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 16, 'data': <psycopg2._json.Json object at 0x0000024134766670>, 'meta': <psycopg2._json.Json object at 0x0000024134766910>}
# {'sample_id': 17, 'data': <psycopg2._json.Json object at 0x0000024134766910>, 'meta': <psycopg2._json.Json object at 0x0000024134766850>}
# {'sample_id': 18, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766910>}
# {'sample_id': 19, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 20, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766850>}
# {'sample_id': 21, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 22, 'data': <psycopg2._json.Json object at 0x0000024134766670>, 'meta': <psycopg2._json.Json object at 0x0000024134766910>}
# {'sample_id': 23, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 24, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766850>}
# {'sample_id': 25, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 26, 'data': <psycopg2._json.Json object at 0x0000024134766670>, 'meta': <psycopg2._json.Json object at 0x0000024134766910>}
# {'sample_id': 27, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 28, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766850>}
# {'sample_id': 29, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 30, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766850>}
# {'sample_id': 31, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766910>}
# {'sample_id': 32, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 33, 'data': <psycopg2._json.Json object at 0x0000024134766670>, 'meta': <psycopg2._json.Json object at 0x0000024134766910>}
# {'sample_id': 34, 'data': <psycopg2._json.Json object at 0x0000024134766910>, 'meta': <psycopg2._json.Json object at 0x0000024134766850>}
# {'sample_id': 35, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766910>}
# {'sample_id': 36, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766670>}
# {'sample_id': 37, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134766850>}
# {'sample_id': 38, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 39, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 40, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 41, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 42, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 43, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 44, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 45, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 46, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 47, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 48, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 49, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 50, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 51, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 52, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 53, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 54, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 55, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 56, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 57, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 58, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 59, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 60, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 61, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 62, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 63, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 64, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 65, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 66, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 67, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 68, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 69, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 70, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 71, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 72, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 73, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 74, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 75, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 76, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 77, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 78, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 79, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 80, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 81, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 82, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 83, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 84, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 85, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 86, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 87, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 88, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 89, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 90, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 91, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 92, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 93, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 94, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 95, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 96, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 97, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 98, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 99, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 100, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 101, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 102, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 103, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 104, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 105, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 106, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 107, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 108, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 109, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 110, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 111, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 112, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 113, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 114, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 115, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 116, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 117, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 118, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 119, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 120, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 121, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 122, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 123, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 124, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 125, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 126, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 127, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 128, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 129, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 130, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 131, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 132, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 133, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 134, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 135, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 136, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 137, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 138, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 139, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 140, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 141, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 142, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 143, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 144, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 145, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 146, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 147, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 148, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 149, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 150, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 151, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 152, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 153, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 154, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 155, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 156, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 157, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 158, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 159, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 160, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 161, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 162, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 163, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 164, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 165, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 166, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 167, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 168, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 169, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 170, 'data': <psycopg2._json.Json object at 0x0000024134743EB0>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 171, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 172, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 173, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 174, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 175, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743D30>}
# {'sample_id': 176, 'data': <psycopg2._json.Json object at 0x0000024134743D30>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
# {'sample_id': 177, 'data': <psycopg2._json.Json object at 0x0000024134743DF0>, 'meta': <psycopg2._json.Json object at 0x0000024134743EB0>}
# {'sample_id': 178, 'data': <psycopg2._json.Json object at 0x0000024134766850>, 'meta': <psycopg2._json.Json object at 0x0000024134743DF0>}
