# %%
import pandas as pd
import numpy as np

# %%
fpath = 'db_feed\P3HT\Literature\Literature_1\L1.xlsx'

f = pd.ExcelFile(fpath)

# %%
sheet_names = f.sheet_names

df = pd.read_excel(fpath, sheet_name=sheet_names[6])
df
# Out:
# C:\Users\aliu319\Anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                                    Device Performance  \
# 0                                      Instructions:
# 1                                                 NaN
# 2                                                 KEY
# 3             Device Measurement - measurement method
# 4        Device Measurement - measurement environment
# 5        Device Measurement - measurement temperature
# 6                Device Measurement - equipment model
# 7    Device Measurement - number of channels measured
# 8   Device Measurement - number of substrates meas...
# 9                    Hole Mobility - reported average
# 10                   Hole Mobility - reported forward
# 11                  Hole Mobility - reported backward
# 12               Electron Mobility - reported average
# ...
